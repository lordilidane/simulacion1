# %%
def aleatorio(x0):
    x  = pow(x0,2)
    strtingx = str(x)
    #print("len")
    #print(len(strtingx))
    if(len(strtingx)<8):
        #poner cero en inicio   
        strtingx = "0"+strtingx
        xi = int(strtingx[2:6])
    else:      
        xi = int(strtingx[2:6])
    #print("xi")
    #print(xi)
    return xi


def iteraciones(iteraciones): 
    xi = aleatorio(x0)
    iteraciones  = iteraciones -1
    #print("segundo xi ")
    #print(xi)
    for x in range(100):   
        xi = aleatorio(xi)
        #print("xi for ")
        #print (xi)
        #print("respuesta")
        print(float(xi)/10000)
    return xi

x0 = 3708

print(iteraciones(100))
# Out:
# 0.13
# 0.69
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 0.41
# 0.81
# 0.61
# 0.21
# 2100
